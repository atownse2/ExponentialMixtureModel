# %%
import sys
sys.path.append("/project01/ndcms/atownse2/ExponentialMixtureModel")

import ROOT

from tools import scale_out as so
import emm
import model_selection as ms
# Out:
# Welcome to JupyROOT 6.30/04

# %% [markdown]
# # ATLAS

# %% [markdown]
# https://www.hepdata.net/record/ins1759712

# %%
import yaml
import array
import ROOT

def create_root_objects(yaml_file):
    # Load the YAML content
    with open(yaml_file, 'r') as f:
        data = yaml.safe_load(f)

    # 1. Extract Bin Edges from independent_variables
    # We take the 'low' from all bins and the 'high' from the last bin
    mjj_bins = data['independent_variables'][0]['values']
    bin_edges = [float(b['low']) for b in mjj_bins]
    bin_edges.append(float(mjj_bins[-1]['high']))
    bin_edges.append(10_000.0)  # Add a bin of zeros beyond the last bin edge
    
    # Convert to a double array for ROOT
    edges_array = array.array('d', bin_edges)
    n_bins = len(bin_edges) - 1

    # 2. Initialize Histograms
    h_observed = ROOT.TH1D("h_observed", "Observed Events;m_{jj} [GeV];Events", n_bins, edges_array)
    h_fit = ROOT.TH1D("h_fit", "Fit Results;m_{jj} [GeV];Events", n_bins, edges_array)

    # 3. Fill Observed Data (First dependent variable)
    obs_data = data['dependent_variables'][0]['values']
    obs_data.append({'value': 0})  # Add a zero entry for the extra bin
    for i, entry in enumerate(obs_data):
        # ROOT bins are 1-indexed
        h_observed.SetBinContent(i + 1, float(entry['value']))
        # Poisson error is standard for observed counts if not provided
        # h_observed.SetBinError(i + 1, ROOT.TMath.Sqrt(float(entry['value'])))

    # 4. Fill Fit Data (Second dependent variable)
    fit_data = data['dependent_variables'][1]['values']
    for i, entry in enumerate(fit_data):
        val = float(entry['value'])
        err = float(entry['errors'][0]['symerror'])
        h_fit.SetBinContent(i + 1, val)
        h_fit.SetBinError(i + 1, err)

    # # 5. Save to a ROOT file
    # output_file = "HEPData_Output.root"
    # f_out = ROOT.TFile(output_file, "RECREATE")
    # h_observed.Write()
    # h_fit.Write()
    # f_out.Close()
    return h_observed, h_fit

    # print(f"Successfully created {output_file} with histograms 'h_observed' and 'h_fit'.")

h_obs, h_fit = create_root_objects('/project01/ndcms/atownse2/ExponentialMixtureModel/data/dijet_ATLAS/HEPData-ins1759712-v1-Table_2.yaml')
print(f"h_obs integral: {h_obs.Integral()}, h_fit integral: {h_fit.Integral()}")
# Out:
# h_obs integral: 28619185.0, h_fit integral: 28619309.650748283

# %%
# Get binning from data
xaxis = h_obs.GetXaxis()
boundaries = [xaxis.GetBinLowEdge(i) for i in range(1, xaxis.GetNbins() + 2)]
binning = ROOT.RooBinning(len(boundaries) - 1, array.array('d', boundaries))

x = ROOT.RooRealVar("x", "m_{jj}", boundaries[0], boundaries[-1])
x.setBinning(binning)

data = ROOT.RooDataHist("ATLAS_dijet_data", "ATLAS dijet data", ROOT.RooArgList(x), h_obs)
print(f"Data mean: {data.mean(x)}")

# SW -- Dijet Paper Fit
dh_fit = ROOT.RooDataHist("dh_fit", "dh_fit", ROOT.RooArgList(x), h_fit)
pdf_fit = ROOT.RooHistPdf("pdf_fit", "pdf_fit", ROOT.RooArgSet(x), dh_fit)

fit_options = [
    ROOT.RooFit.IntegrateBins(0.0001),
    ROOT.RooFit.PrintLevel(-1),
    ROOT.RooFit.Offset(True),
    # ROOT.RooFit.Strategy(2),
    ROOT.RooFit.Save(),
    # ROOT.RooFit.Range("fit_range")
]
# Out:
# Data mean: 1347.5082817871998

# %% [markdown]
# ## Model Selection

# %%
# Configuration
model_primitives = [
    emm.ExponentialMixtureModel_2_Dijet,
    emm.ExponentialMixtureModel_3_Dijet,
    emm.ExponentialMixtureModel_4_Dijet,
    emm.ExponentialMixtureModel_5_Dijet,
    emm.ExponentialMixtureModel_6_Dijet,
]

seed = 42
n_random_restarts = 80
n_retries = 100

# %%
# Run jobs
import os

remake = False
# remake = True

tasks = []
for mp in model_primitives:
    model = mp(x)
    filename = emm.random_restarts_filename(
        model.name,
        data.GetName(),
        n_random_restarts,
        seed,
    )
    if os.path.exists(filename):
        if remake:
            pass
        else:
            print(f"File {filename} already exists. Skipping {model.name}.")
            continue

    task = so.Task(
        emm.fit_random_restarts,
        x, data, mp,
        seed, n_random_restarts,
        n_retries=n_retries,
        save=True,
        fit_options=fit_options
    )
    tasks.append(task)

_ = so.run_tasks(
    tasks,
    use_condor=True,
    condor_job_name="emm_model_selection_dijet",
    env_wrapper=so.run_in_mamba,
)
# Out:
# Submitting 5 tasks to condor with job name 'emm_model_selection_dijet'

# %%
import pickle
import os

results = {}
for mp in model_primitives:
    name = mp.name
    k = int(name.split("-")[-1])

    # model = emm.ExponentialMixtureModel(x, k, data_mean=data.mean(x))
    model = mp(x)
    filename = emm.random_restarts_filename(
        model.name,
        data.GetName(),
        n_random_restarts,
        seed,
    )
    if not os.path.exists(filename):
        print(f"File {filename} does not exist. Skipping.")
        continue
    with open(filename, 'rb') as f:
        fit_result = pickle.load(f)
    results[k] = fit_result

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax1 = plt.subplots(1, figsize=(8, 3))

ks_to_plot = []
AICs = []
BICs = []

# Assuming 'results', 'x', 'mp', and 'h_obs' are defined in your environment
for k, result in results.items():
    if k == 2: continue
    best_result = result[-1]
    # model = emm.ExponentialMixtureModel(x, k, data_mean=data.mean(x))
    model = mp(x)
    model.set_params(best_result['final_pars'])
    nll = best_result['nll']
    n = h_obs.Integral()
    AIC = 2*(2*k-1) + 2*nll
    BIC = (2*k-1)*np.log(n) + 2*nll
    ks_to_plot.append(k)
    AICs.append(AIC)
    BICs.append(BIC)

# --- Plot AIC on the primary (left) y-axis ---
ax1.scatter(ks_to_plot, AICs, color='red', label="AIC")
ax1.set_xlabel('Number of Components (k)')
ax1.set_ylabel('AIC', color='red')
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_xticks(ks_to_plot)

# --- Create a secondary (right) y-axis ---
ax2 = ax1.twinx()

# --- Plot BIC on the secondary y-axis ---
ax2.scatter(ks_to_plot, BICs, color='blue', label="BIC", marker='x')
ax2.set_ylabel('BIC', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# --- Combine legends from both axes into one ---
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(handles1 + handles2, labels1 + labels2, loc='upper center')

# Use tight_layout so the right-side label doesn't get cut off
fig.tight_layout() 
plt.show()

# %%
# Fitting
n_data = h_obs.Integral()

# Dijet Fit
dijet_model = emm.Dijet(x)
fit_result = dijet_model.pdf.fitTo(data, *fit_options)
print("Dijet Fit Results:")

nll = fit_result.minNll()
n_params = 3
AIC = 2*n_params + 2*nll
BIC = n_params*np.log(n_data) + 2*nll
print(f"Dijet Fit: nll={nll:.2f}, AIC={AIC:.2f}, BIC={BIC:.2f}")

# Exponential Mixture Model Fit
# fit_options.append(ROOT.RooFit.Strategy(2))
k=4
n_params = 2*k - 1
# expmix = emm.ExponentialMixtureModel(x, k, data_mean=data.mean(x))
expmix = emm.ExponentialMixtureModel_4_Dijet(x)
best_fit_pars = results[k][-1]['final_pars']
expmix.set_params(best_fit_pars)

nll = results[k][-1]['nll']
AIC = 2*n_params + 2*nll
BIC = n_params*np.log(n_data) + 2*nll
print(f"Exponential Mixture Model k={k} Fit Results: nll={nll:.2f}, AIC={AIC:.2f}, BIC={BIC:.2f}")

# Print results

expmix.print()

models = [
    # pdf_fit,
    dijet_model.pdf,
    expmix.pdf
]
model_labels = [
    # "SW Dijet Fit",
    "Dijet Function",
    f"Exponential Mixture (AIC)"
    ]
# Out:
# Dijet Fit Results:
# Dijet Fit: nll=186084288.12, AIC=372168582.25, BIC=372168627.76
# Exponential Mixture Model k=4 Fit Results: nll=186084283.99, AIC=372168581.97, BIC=372168688.16
# Model: ExponentialMixture-4
# raw_rate_0: 2.134861202110175 + -1.0 1.0
# raw_rate_1: 0.8300432617080732 + -1.0 1.0
# raw_rate_2: 0.5171394909409159 + -1.0 1.0
# raw_rate_3: 1.285988270568433 + -1.0 1.0
# raw_weight_0: 0.0 + -1.0 1.0
# raw_weight_1: 1.0788560560893563 + -1.0 1.0
# raw_weight_2: 0.2915717910323344 + -1.0 1.0
# raw_weight_3: 0.8699945101538207 + -1.0 1.0
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %%
emm.plot_fits(
    data, x, models,
    model_labels=model_labels,
    # title="ATLAS Dijet Spectrum",
    )
# Out:
# [#0] ERROR:InputArguments -- RooAbsReal::plotOn(Dijet) ERROR: unrecognized command: IntegrateBins
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#0] ERROR:InputArguments -- RooAbsReal::plotOn(ExponentialMixture-4) ERROR: unrecognized command: IntegrateBins

# %% [markdown]
# # CMS

# %%
# Now lets try the CMS result
# https://www.hepdata.net/record/ins1764471
yaml_file = "/project01/ndcms/atownse2/ExponentialMixtureModel/data/dijet_CMS/dijet.yaml"
import ROOT
import yaml
import array

def load_hepdata_to_histogram(yaml_file_path):
    """
    Parses HEPData YAML and returns a ROOT TH1D histogram.
    """
    with open(yaml_file_path, 'r') as f:
        data = yaml.safe_load(f)

    # 1. Extract bin edges from independent_variables
    # We take the 'low' value of the first bin and 'high' values of all bins
    bin_info = data['independent_variables'][0]['values']
    bin_edges = [bin_info[0]['low']]
    for b in bin_info:
        bin_edges.append(b['high'])
    
    # Convert list to a double array for ROOT
    edges_array = array.array('d', bin_edges)
    num_bins = len(bin_edges) - 1

    # 2. Initialize the TH1D
    h_obs = ROOT.TH1D(
        "data",
        "Observed Dijet Events;Dijet mass [GeV];Events",
        num_bins,
        edges_array
    )
    # h_obs.Sumw2()  # Enable storage of sum of squares of weights for error
    h_xs = ROOT.TH1D(
        "cross_section",
        "Dijet Cross-section;Dijet mass [GeV];Cross-section [pb/GeV]",
        num_bins,
        edges_array
    )
    # h_xs.Sumw2()  # Enable storage of sum of squares of weights for

    # 3. Extract Observed Event values
    obs_data = data['dependent_variables'][0]
    values = obs_data['values']
    for i, entry in enumerate(values):
        val = entry['value']
        h_obs.SetBinContent(i + 1, val)
        # print(f"Bin {i+1}: Observed Events = {val}, Edges = [{h_obs.GetBinLowEdge(i+1)}, {h_obs.GetBinLowEdge(i+2)}]")

    # 4. Extract Cross-section values and errors
    # Note: Cross-section is the second dependent variable in your file
    xs_data = data['dependent_variables'][1]
    values = xs_data['values']
    for i, entry in enumerate(values):
        val = entry['value']
        # HEPData often provides asymmetric errors (plus/minus)
        # ROOT TH1 only supports symmetric errors; we take the average or the 'plus' error.
        err_info = entry['errors'][0]['asymerror']
        err_plus = abs(err_info['plus'])
        err_minus = abs(err_info['minus'])
        avg_err = (err_plus + err_minus) / 2.0

        # ROOT bins are 1-indexed (bin 0 is underflow)
        # print(f"Bin {i+1}: Value = {val}, Error = {avg_err}"    )
        h_xs.SetBinContent(i + 1, val)
        h_xs.SetBinError(i + 1, avg_err)
    # hist.Sumw2()  # Ensure errors are stored correctly
    return h_obs, h_xs

# Example usage:
h_obs, h_xs = load_hepdata_to_histogram(yaml_file)

# %%
# Fit the model they use in the dijet paper for comparison
x = ROOT.RooRealVar("x", "x", h_obs.GetXaxis().GetXmin(), h_obs.GetXaxis().GetXmax())
boundaries = [h_obs.GetXaxis().GetBinLowEdge(i) for i in range(1, h_obs.GetXaxis().GetNbins() + 2)]
binning = ROOT.RooBinning(len(boundaries) - 1, array.array('d', boundaries))
x.setBinning(binning)

data = ROOT.RooDataHist("data", "data", ROOT.RooArgList(x), ROOT.RooFit.Import(h_obs))

fit_options = [
    ROOT.RooFit.IntegrateBins(0.001),
    ROOT.RooFit.PrintLevel(-1),
    ROOT.RooFit.Offset(True),
    ROOT.RooFit.Save()
]

dijet_model = emm.Dijet3(x)
result = dijet_model.pdf.fitTo(data, *fit_options)
_ = chi2(dijet_model.pdf, data)
# print("Fit Result from default initialization:", result.status())

k=3
expmix = emm.ExponentialMixtureModel(x, k, data_mean=data.mean(x))
expmix.pdf.fitTo(data, *fit_options)
_ = chi2(expmix.pdf, data)

emm.plot_fits(
    data, x, [dijet_model.pdf, expmix.pdf],
    model_labels=["Dijet 4 Param Fit", f"EMM k={k} Fit"],
    title="CMS Dijet Spectrum Fit",
    y_min=1e-3,
)
# Out:
# Chi2: 173.48467681669567, NDF: 39, Reduced Chi2: 4.448325046581941
# Chi2: 171.01025140990922, NDF: 37, Reduced Chi2: 4.621898686754303
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (pdf_0,pdf_1,pdf_2)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- RooAbsReal::plotOn(Dijet3) ERROR: unrecognized command: IntegrateBins
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#0] ERROR:InputArguments -- RooAbsReal::plotOn(ExponentialMixture_3) ERROR: unrecognized command: IntegrateBins

# %%
# Fit the model they use in the dijet paper for comparison
x = ROOT.RooRealVar("x", "x", h_obs.GetXaxis().GetXmin(), h_obs.GetXaxis().GetXmax())
boundaries = [h_obs.GetXaxis().GetBinLowEdge(i) for i in range(1, h_obs.GetXaxis().GetNbins() + 2)]
binning = ROOT.RooBinning(len(boundaries) - 1, array.array('d', boundaries))
x.setBinning(binning)

data = ROOT.RooDataHist("data", "data", ROOT.RooArgList(x), ROOT.RooFit.Import(h_obs))

dijet_model = emm.Dijet3(x)
result = dijet_model.pdf.fitTo(data, ROOT.RooFit.Save(), ROOT.RooFit.IntegrateBins(0.001), ROOT.RooFit.PrintLevel(-1))
print("Fit Result from default initialization:", result.status())

# Lets add a trigger model
mu = ROOT.RooRealVar("mu", "mu", 1250, 1000, 2000)
s = ROOT.RooRealVar("s", "s", 250, 10, 500)

cdf = ROOT.RooFormulaVar(
    "cdf"
    "Gaussian CDF",
    f"0.5*(1 + TMath::Erf(({x.GetName()} - {mu.GetName()})/(sqrt(2)*{s.GetName()})))",
    ROOT.RooArgList(x, mu, s)
)

k=3
expmix = emm.ExponentialMixtureModel(x, k, data_mean=data.mean(x))
expmix.pdf.fitTo(data, ROOT.RooFit.Save(), ROOT.RooFit.IntegrateBins(0.001), ROOT.RooFit.PrintLevel(-1))
print("EMM Fit Result from default initialization:", result.status())
expmix.print()

full_model = ROOT.RooEffProd("full_model", "full_model", expmix.pdf, cdf)
full_model.fitTo(data, ROOT.RooFit.IntegrateBins(0.001), ROOT.RooFit.PrintLevel(-1), ROOT.RooFit.Save())

emm.plot_fits(
    data, x,
    [dijet_model.pdf, full_model],
    model_labels=["Dijet 4 Param Fit", f"EMM k={k} Fit with Trigger"],
    title="CMS Dijet Spectrum Fit",
    y_min=1e-5,
    # logx=True,
    # colors=[ROOT.kGreen],
    # binning=binning,
    # plot_range=(1100, 1500),
)
# model.print()
# Out:
# Fit Result from default initialization: 1
# EMM Fit Result from default initialization: 1
# Model: ExponentialMixture_3
# raw_rate_0: 0.6330502035873551 + 0.0038692579018545503 -0.0038692579018545503
# raw_rate_1: 1.0538493490296454 + 0.004066463140378618 -0.004066463140378618
# raw_rate_2: 1.803086996649734 + 0.014939797174003844 -0.014939797174003844
# raw_weight_0: 0.995365398991201 + 0.06716573953382382 -0.06716573953382382
# raw_weight_1: 2.1952583462451374 + 0.06705245275726278 -0.06705245275726278
# raw_weight_2: 0.0
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (pdf_0,pdf_1,pdf_2)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(full_model_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (pdf_0,pdf_1,pdf_2)
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.41856e+07) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mu=1961.65	raw_rate_0=238.322	raw_rate_1=742.066	raw_rate_2=805.33	raw_weight_0=-109.485	raw_weight_1=86.1316	s=477.785
# RooNLLVar::nll_full_model_data[ parameters=(mu,raw_rate_0,raw_rate_1,raw_rate_2,raw_weight_0,raw_weight_1,raw_weight_2,s) ]
#      function value is NAN @ parameters=(mu = 1961.65,raw_rate_0 = 238.322 +/- 0.00386926,raw_rate_1 = 742.066 +/- 0.00406646,raw_rate_2 = 805.33 +/- 0.0149398,raw_weight_0 = -109.485 +/- 0.0671657,raw_weight_1 = 86.1316 +/- 0.0670525,raw_weight_2 = 0,s = 477.785)
# RooBinSamplingPdf::full_model_binSampling[ inputPdf=full_model observable=x ]
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1568.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1647
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1728.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1813
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1900.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1991
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2084.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2181.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2281.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2385
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2492
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2602.5
#     ... (remaining 31 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.41856e+07) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mu=1820.32	raw_rate_0=934.458	raw_rate_1=245.035	raw_rate_2=742.473	raw_weight_0=-54.257	raw_weight_1=44.195	s=439.512
# RooNLLVar::nll_full_model_data[ parameters=(mu,raw_rate_0,raw_rate_1,raw_rate_2,raw_weight_0,raw_weight_1,raw_weight_2,s) ]
#      function value is NAN @ parameters=(mu = 1820.32,raw_rate_0 = 934.458 +/- 0.00386926,raw_rate_1 = 245.035 +/- 0.00406646,raw_rate_2 = 742.473 +/- 0.0149398,raw_weight_0 = -54.257 +/- 0.0671657,raw_weight_1 = 44.195 +/- 0.0670525,raw_weight_2 = 0,s = 439.512)
# RooBinSamplingPdf::full_model_binSampling[ inputPdf=full_model observable=x ]
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1568.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1647
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1728.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1813
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1900.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1991
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2084.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2181.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2281.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2385
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2492
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2602.5
#     ... (remaining 31 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.41856e+07) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mu=1530.23	raw_rate_0=631.765	raw_rate_1=935.034	raw_rate_2=267.826	raw_weight_0=-26.643	raw_weight_1=23.2268	s=322.518
# RooNLLVar::nll_full_model_data[ parameters=(mu,raw_rate_0,raw_rate_1,raw_rate_2,raw_weight_0,raw_weight_1,raw_weight_2,s) ]
#      function value is NAN @ parameters=(mu = 1530.23,raw_rate_0 = 631.765 +/- 0.00386926,raw_rate_1 = 935.034 +/- 0.00406646,raw_rate_2 = 267.826 +/- 0.0149398,raw_weight_0 = -26.643 +/- 0.0671657,raw_weight_1 = 23.2268 +/- 0.0670525,raw_weight_2 = 0,s = 322.518)
# RooBinSamplingPdf::full_model_binSampling[ inputPdf=full_model observable=x ]
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1568.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1647
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1728.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1813
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1900.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1991
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2084.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2181.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2281.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2385
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2492
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2602.5
#     ... (remaining 31 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.41856e+07) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mu=1627.06	raw_rate_0=199.691	raw_rate_1=626.286	raw_rate_2=85.4494	raw_weight_0=-12.836	raw_weight_1=12.7426	s=256.86
# RooNLLVar::nll_full_model_data[ parameters=(mu,raw_rate_0,raw_rate_1,raw_rate_2,raw_weight_0,raw_weight_1,raw_weight_2,s) ]
#      function value is NAN @ parameters=(mu = 1627.06,raw_rate_0 = 199.691 +/- 0.00386926,raw_rate_1 = 626.286 +/- 0.00406646,raw_rate_2 = 85.4494 +/- 0.0149398,raw_weight_0 = -12.836 +/- 0.0671657,raw_weight_1 = 12.7426 +/- 0.0670525,raw_weight_2 = 0,s = 256.86)
# RooBinSamplingPdf::full_model_binSampling[ inputPdf=full_model observable=x ]
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=2835
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=2957
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=3083
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=3213
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=3347.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=3487
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=3631
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=3779
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=3932
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=4090.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=4254
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/1.94468e-05, observable=x=4423
#     ... (remaining 18 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.41856e+07) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mu=1957.43	raw_rate_0=945.547	raw_rate_1=806.606	raw_rate_2=970.369	raw_weight_0=-5.9325	raw_weight_1=7.50057	s=497.213
# RooNLLVar::nll_full_model_data[ parameters=(mu,raw_rate_0,raw_rate_1,raw_rate_2,raw_weight_0,raw_weight_1,raw_weight_2,s) ]
#      function value is NAN @ parameters=(mu = 1957.43,raw_rate_0 = 945.547 +/- 0.00386926,raw_rate_1 = 806.606 +/- 0.00406646,raw_rate_2 = 970.369 +/- 0.0149398,raw_weight_0 = -5.9325 +/- 0.0671657,raw_weight_1 = 7.50057 +/- 0.0670525,raw_weight_2 = 0,s = 497.213)
# RooBinSamplingPdf::full_model_binSampling[ inputPdf=full_model observable=x ]
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1568.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1647
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1728.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1813
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1900.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1991
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2084.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2181.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2281.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2385
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2492
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2602.5
#     ... (remaining 31 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.41856e+07) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mu=1356.83	raw_rate_0=379.543	raw_rate_1=718.809	raw_rate_2=610.26	raw_weight_0=-2.48075	raw_weight_1=4.87954	s=385.703
# RooNLLVar::nll_full_model_data[ parameters=(mu,raw_rate_0,raw_rate_1,raw_rate_2,raw_weight_0,raw_weight_1,raw_weight_2,s) ]
#      function value is NAN @ parameters=(mu = 1356.83,raw_rate_0 = 379.543 +/- 0.00386926,raw_rate_1 = 718.809 +/- 0.00406646,raw_rate_2 = 610.26 +/- 0.0149398,raw_weight_0 = -2.48075 +/- 0.0671657,raw_weight_1 = 4.87954 +/- 0.0670525,raw_weight_2 = 0,s = 385.703)
# RooBinSamplingPdf::full_model_binSampling[ inputPdf=full_model observable=x ]
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1568.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1647
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1728.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1813
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1900.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1991
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2084.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2181.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2281.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2385
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2492
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2602.5
#     ... (remaining 31 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.41856e+07) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mu=1994.97	raw_rate_0=103.768	raw_rate_1=233.851	raw_rate_2=792.498	raw_weight_0=-0.754876	raw_weight_1=3.56902	s=287.771
# RooNLLVar::nll_full_model_data[ parameters=(mu,raw_rate_0,raw_rate_1,raw_rate_2,raw_weight_0,raw_weight_1,raw_weight_2,s) ]
#      function value is NAN @ parameters=(mu = 1994.97,raw_rate_0 = 103.768 +/- 0.00386926,raw_rate_1 = 233.851 +/- 0.00406646,raw_rate_2 = 792.498 +/- 0.0149398,raw_weight_0 = -0.754876 +/- 0.0671657,raw_weight_1 = 3.56902 +/- 0.0670525,raw_weight_2 = 0,s = 287.771)
# RooBinSamplingPdf::full_model_binSampling[ inputPdf=full_model observable=x ]
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=2385
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=2492
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=2602.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=2717
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=2835
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=2957
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=3083
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=3213
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=3347.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=3487
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=3631
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0.000689774, observable=x=3779
#     ... (remaining 22 messages suppressed)
#
# RooAbsMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (1.82604e+08) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	mu=1433.94	raw_rate_0=258.28	raw_rate_1=753.748	raw_rate_2=566.82	raw_weight_0=0.923203	raw_weight_1=2.2948	s=497.689
# RooNLLVar::nll_full_model_data[ parameters=(mu,raw_rate_0,raw_rate_1,raw_rate_2,raw_weight_0,raw_weight_1,raw_weight_2,s) ]
#      function value is NAN @ parameters=(mu = 1433.94,raw_rate_0 = 258.28 +/- 0.00386926,raw_rate_1 = 753.748 +/- 0.00406646,raw_rate_2 = 566.82 +/- 0.0149398,raw_weight_0 = 0.923203 +/- 0.0671657,raw_weight_1 = 2.2948 +/- 0.0670525,raw_weight_2 = 0,s = 497.689)
# RooBinSamplingPdf::full_model_binSampling[ inputPdf=full_model observable=x ]
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1568.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1647
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1728.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1813
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1900.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=1991
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2084.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2181.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2281.5
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2385
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2492
#      getLogVal() top-level p.d.f evaluates to zero @ inputPdf=full_model=0/0, observable=x=2602.5
#     ... (remaining 31 messages suppressed)
#
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(full_model_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)

# %%
print(f"mu: {mu.getValV()}, s: {s.getValV()}")
# Out:
# mu: 1221.7807441489147, s: 100.21657644654428

# %%
# Generate a dataset from the Dijet model and fit with EMM
# toy_data = dijet_model.pdf.generate(ROOT.RooArgSet(x), int(data.sumEntries()))
toy_data = dijet_model.pdf.generate(ROOT.RooArgSet(x), int(1_000_000))

# Set binning for x
boundaries = [h_obs.GetXaxis().GetBinLowEdge(i) for i in range(1, h_obs.GetXaxis().GetNbins() + 2)]
binning = ROOT.RooBinning(len(boundaries) - 1, array.array('d', boundaries))
x.setBinning(binning)

toy_model = emm.Dijet3(x)
toy_result = toy_model.pdf.fitTo(toy_data, ROOT.RooFit.Save())
print("Toy Dijet Fit Result from default initialization:", toy_result.status())

emm_model = emm.ExponentialMixtureModel(x, 3, data_mean=data.mean(x))
emm_result = emm_model.pdf.fitTo(toy_data, ROOT.RooFit.Save())
print("EMM Fit Result from default initialization:", emm_result.status())

emm.plot_fits(
    toy_data,
    x, [toy_model.pdf, emm_model.pdf],
    model_labels=["Toy Dijet 4 Param Fit", "EMM Fit"],
    # colors=[ROOT.kGreen],
    # binning=binning,
    # plot_range=(1100, 1500),
)
toy_model.print()
# Out:
# Toy Dijet Fit Result from default initialization: 1
# EMM Fit Result from default initialization: 1
# Model: Dijet3
# p1: -1.4153638170339462 + 0.7690728176999513 -0.7690728176999513
# p2: -13.219462790268496 + 0.5699638225986696 -0.5699638225986696
# p3: -1.6759722001101733 + 0.11449983863398372 -0.11449983863398372
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 1500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 1
# FVAL  = 6737644.93564675283
# Edm   = 0.000128894148095677434
# Nfcn  = 212
# p1	  = -1.41536	 +/-  0.170079	(limited)
# p2	  = -13.2195	 +/-  0.0909081	(limited)
# p3	  = -1.67597	 +/-  0.0183877	(limited)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (pdf_0,pdf_1,pdf_2)
# Minuit2Minimizer: Minimize with max-calls 2500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 1
# FVAL  = 6737642.3622914236
# Edm   = 0.00848080522100751188
# Nfcn  = 323
# raw_rate_0	  = 0.556784	 +/-  0.0108694	(limited)
# raw_rate_1	  = 1.00764	 +/-  0.0110328	(limited)
# raw_rate_2	  = 1.61036	 +/-  0.0315991	(limited)
# raw_weight_0	  = -0.24313	 +/-  0.214232
# raw_weight_1	  = 1.59463	 +/-  0.171005
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       6801824.242 Edm =       146881.6756 NCalls =     19
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 6801824.242
#   Edm           : 146881.6756
#   Internal parameters:	[    -0.2013579208    -0.5235987756    -0.1001674212]
#   Internal gradient  :	[      693220.0514     -3024450.462       12512591.1]
#   Internal covariance matrix:
# [[  5.0120142e-07              0              0]
#  [              0  2.0439088e-08              0]
#  [              0              0   1.020087e-09]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 1500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       6801824.242 Edm =       146881.6756 NCalls =     19
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       6771395.774 Edm =       50195.08038 NCalls =     31
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       6756720.182 Edm =       895.4810855 NCalls =     39
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       6746915.092 Edm =       191.7669234 NCalls =     54
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =       6746850.789 Edm =       96.28611539 NCalls =     62
# Info in <Minuit2>: VariableMetricBuilder    5 - FCN =       6746786.863 Edm =       8.672785348 NCalls =     70
# Info in <Minuit2>: VariableMetricBuilder    6 - FCN =       6746535.526 Edm =       290.1663965 NCalls =     81
# Info in <Minuit2>: VariableMetricBuilder    7 - FCN =       6746002.337 Edm =       490.5425425 NCalls =     94
# Info in <Minuit2>: VariableMetricBuilder    8 - FCN =       6742579.922 Edm =        1079.90872 NCalls =    104
# Info in <Minuit2>: VariableMetricBuilder    9 - FCN =       6740500.218 Edm =       2665.195897 NCalls =    113
# Info in <Minuit2>: VariableMetricBuilder   10 - FCN =       6739194.441 Edm =       401.3993153 NCalls =    121
# Info in <Minuit2>: VariableMetricBuilder   11 - FCN =       6738230.285 Edm =        198.128139 NCalls =    130
# Info in <Minuit2>: VariableMetricBuilder   12 - FCN =        6737923.23 Edm =       95.49516242 NCalls =    139
# Info in <Minuit2>: VariableMetricBuilder   13 - FCN =       6737743.079 Edm =       33.70111363 NCalls =    148
# Info in <Minuit2>: VariableMetricBuilder   14 - FCN =       6737663.001 Edm =       13.94317566 NCalls =    158
# Info in <Minuit2>: VariableMetricBuilder   15 - FCN =       6737646.563 Edm =       1.039615022 NCalls =    166
# Info in <Minuit2>: VariableMetricBuilder   16 - FCN =       6737645.024 Edm =     0.05910108676 NCalls =    174
# Info in <Minuit2>: VariableMetricBuilder   17 - FCN =       6737644.948 Edm =    0.006760337769 NCalls =    182
# Info in <Minuit2>: VariableMetricBuilder   18 - FCN =       6737644.936 Edm =     0.00013238042 NCalls =    190
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.0036668
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder   19 - FCN =       6737644.936 Edm =   0.0001288941481 NCalls =    212
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Covar was made pos def
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 1500
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is accurate
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       6940921.505 Edm =      -281027.0422 NCalls =     27
# Info in <Minuit2>: NegativeG2LineSearch Doing a NegativeG2LineSearch since one of the G2 component is negative
# Info in <Minuit2>: MnSeedGenerator Negative G2 found - new state:
#   Minimum value : 6743025.003
#   Edm           : 21941.48733
#   Internal parameters:	[     -1.520255249     -1.504451664     -1.479112705                0      1.766705815]
#   Internal gradient  :	[      715233.7352      1886387.575      322229.6856     -4175.783526     -1371.660268]
#   Internal covariance matrix:
# [[  1.8589097e-08              0              0              0              0]
#  [              0  5.9166305e-09              0              0              0]
#  [              0              0   2.382813e-07              0              0]
#  [              0              0              0   0.0017978593              0]
#  [              0              0              0              0  0.00059084703]]]
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 6743025.003
#   Edm           : 21941.48733
#   Internal parameters:	[     -1.520255249     -1.504451664     -1.479112705                0      1.766705815]
#   Internal gradient  :	[      715233.7352      1886387.575      322229.6856     -4175.783526     -1371.660268]
#   Internal covariance matrix:
# [[  1.8589097e-08              0              0              0              0]
#  [              0  5.9166305e-09              0              0              0]
#  [              0              0   2.382813e-07              0              0]
#  [              0              0              0   0.0017978593              0]
#  [              0              0              0              0  0.00059084703]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 2500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       6743025.003 Edm =       21941.48733 NCalls =     73
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       6739402.049 Edm =       7870.888524 NCalls =     89
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =        6737982.62 Edm =       1019.033785 NCalls =    101
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       6737704.955 Edm =       120.6386851 NCalls =    113
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =       6737662.745 Edm =       11.07164671 NCalls =    125
# Info in <Minuit2>: VariableMetricBuilder    5 - FCN =       6737656.522 Edm =      0.2910317357 NCalls =    137
# Info in <Minuit2>: VariableMetricBuilder    6 - FCN =       6737655.668 Edm =      0.3320885955 NCalls =    149
# Info in <Minuit2>: VariableMetricBuilder    7 - FCN =       6737654.629 Edm =     0.03809753504 NCalls =    161
# Info in <Minuit2>: VariableMetricBuilder    8 - FCN =       6737654.464 Edm =      0.1217961762 NCalls =    174
# Info in <Minuit2>: VariableMetricBuilder    9 - FCN =       6737649.247 Edm =       1.654047555 NCalls =    193
# Info in <Minuit2>: VariableMetricBuilder   10 - FCN =       6737647.175 Edm =       3.178967818 NCalls =    206
# Info in <Minuit2>: VariableMetricBuilder   11 - FCN =       6737645.398 Edm =       1.454376137 NCalls =    218
# Info in <Minuit2>: VariableMetricBuilder   12 - FCN =       6737642.973 Edm =      0.2904930152 NCalls =    231
# Info in <Minuit2>: VariableMetricBuilder   13 - FCN =       6737642.367 Edm =     0.02233104005 NCalls =    245
# Info in <Minuit2>: VariableMetricBuilder   14 - FCN =       6737642.363 Edm =    0.006588369455 NCalls =    258
# Info in <Minuit2>: VariableMetricBuilder   15 - FCN =       6737642.362 Edm =    0.003606716595 NCalls =    271
# Warning in <Minuit2>: VariableMetricBuilder No improvement in line search
# Info in <Minuit2>: VariableMetricBuilder   16 - FCN =       6737642.362 Edm =    0.003606716595 NCalls =    282
# Info in <Minuit2>: VariableMetricBuilder Edm is close to limit - return current minimum
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.0184472
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder   17 - FCN =       6737642.362 Edm =    0.008480805221 NCalls =    323
# Warning in <Minuit2>: VariableMetricBuilder Reached machine accuracy limit; Edm 0.00848081 is smaller than machine limit 0.401595 while 0.001 was requested
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Covar was made pos def
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 2500
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 0.00353086
# Info in <Minuit2>: Minuit2Minimizer::Hesse Hesse is valid - matrix is full but made positive defined

# %%
# Do it binned now
toy_data = dijet_model.pdf.generate(ROOT.RooArgSet(x), int(10_000_000))
binned_toy_data = ROOT.RooDataHist("binned_toy_data", "binned_toy_data", ROOT.RooArgList(x), toy_data)

toy_model = emm.Dijet3(x)
toy_result = toy_model.pdf.fitTo(
    binned_toy_data,
    ROOT.RooFit.Save(),
    ROOT.RooFit.IntegrateBins(0.0001),
    ROOT.RooFit.PrintLevel(-1),
    ROOT.RooFit.Offset(True))
print("Toy Dijet Fit Result from default initialization:", toy_result.status())

emm_model = emm.ExponentialMixtureModel(x, 3, data_mean=data.mean(x))
emm_result = emm_model.pdf.fitTo(
    binned_toy_data,
    ROOT.RooFit.Save(),
    ROOT.RooFit.IntegrateBins(0.0001),
    ROOT.RooFit.PrintLevel(-1),
    ROOT.RooFit.Offset(True))
print("EMM Fit Result from default initialization:", emm_result.status())

emm.plot_fits(
    binned_toy_data,
    x, [toy_model.pdf, emm_model.pdf],
    model_labels=["Toy Dijet 4 Param Fit", "EMM Fit"],
    # colors=[ROOT.kGreen],
    # binning=binning,
    # plot_range=(1100, 1500),
)
toy_model.print()
# Out:
# Toy Dijet Fit Result from default initialization: 1
# EMM Fit Result from default initialization: 1
# Model: Dijet3
# p1: 8.295406985650938 + 0.34364649909480516 -0.34364649909480516
# p2: -5.123056330258587 + 0.24833643621826118 -0.24833643621826118
# p3: 0.021712825457305275 + 0.04935354222975773 -0.04935354222975773
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization --  The following expressions will be evaluated in cache-and-track mode: (pdf_0,pdf_1,pdf_2)
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- RooAbsReal::plotOn(Dijet3) ERROR: unrecognized command: IntegrateBins
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Dijet3_Int[x]) using numeric integrator RooRombergIntegrator to calculate Int(x)
# [#0] ERROR:InputArguments -- RooAbsReal::plotOn(ExponentialMixture_3) ERROR: unrecognized command: IntegrateBins
